# %% [markdown]
# <p dir = 'rtl'>    درس سوم بخش دوم </p>

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Mahi/Desktop/project Pandas/Data/nba.csv', index_col='Name')
df.head()
# Out:
#                               Team Position Birthday   Salary
# Name
# Shake Milton    Philadelphia 76ers       SG  9/26/96  1445697
# Christian Wood     Detroit Pistons       PF  9/27/95  1645357
# PJ Washington    Charlotte Hornets       PF  8/23/98  3831840
# Derrick Rose       Detroit Pistons       PG  10/4/88  7317074
# Marial Shayok   Philadelphia 76ers        G  7/26/95    79568

# %%
salary = df['Salary']

# %%
type(df), type(salary)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
len(df)
# Out:
# 450

# %%
len(salary)
# Out:
# 450

# %%
df.size
# Out:
# 1800

# %%
salary.size
# Out:
# 450

# %%
df.shape
# Out:
# (450, 4)

# %%
salary.shape
# Out:
# (450,)

# %%
df.ndim
# Out:
# 2

# %%
salary.ndim
# Out:
# 1

# %%
df.dtypes
# Out:
# Team        object
# Position    object
# Birthday    object
# Salary       int64
# dtype: object

# %%
salary.dtype
# Out:
# dtype('int64')

# %%
salary.dtypes
# Out:
# dtype('int64')

# %%
df.count()
# Out:
# Team        450
# Position    450
# Birthday    450
# Salary      450
# dtype: int64

# %%
salary.count()
# Out:
# 450

# %%
df.head()
# Out:
#                               Team Position Birthday   Salary
# Name
# Shake Milton    Philadelphia 76ers       SG  9/26/96  1445697
# Christian Wood     Detroit Pistons       PF  9/27/95  1645357
# PJ Washington    Charlotte Hornets       PF  8/23/98  3831840
# Derrick Rose       Detroit Pistons       PG  10/4/88  7317074
# Marial Shayok   Philadelphia 76ers        G  7/26/95    79568

# %%
salary.head()
# Out:
# Name
# Shake Milton      1445697
# Christian Wood    1645357
# PJ Washington     3831840
# Derrick Rose      7317074
# Marial Shayok       79568
# Name: Salary, dtype: int64

# %%
df.describe()
# Out:
#              Salary
# count  4.500000e+02
# mean   7.653584e+06
# std    9.288810e+06
# min    7.956800e+04
# 25%    1.618520e+06
# 50%    3.303074e+06
# 75%    1.012957e+07
# max    4.023176e+07

# %%
salary.describe()
# Out:
# count    4.500000e+02
# mean     7.653584e+06
# std      9.288810e+06
# min      7.956800e+04
# 25%      1.618520e+06
# 50%      3.303074e+06
# 75%      1.012957e+07
# max      4.023176e+07
# Name: Salary, dtype: float64

# %%
df2 = pd.read_csv('C:/Users/Mahi/Desktop/project Pandas/Data/employees.csv', index_col='First Name')
df.head()
# Out:
#                               Team Position Birthday   Salary
# Name
# Shake Milton    Philadelphia 76ers       SG  9/26/96  1445697
# Christian Wood     Detroit Pistons       PF  9/27/95  1645357
# PJ Washington    Charlotte Hornets       PF  8/23/98  3831840
# Derrick Rose       Detroit Pistons       PG  10/4/88  7317074
# Marial Shayok   Philadelphia 76ers        G  7/26/95    79568

# %%
df2.sort_values(by='Team').head(10)
# Out:
#             Gender Start Date    Salary   Mgmt          Team
# First Name
# Sharon         NaN     3/1/90   83658.0  False  Business Dev
# Doris       Female     7/5/93  141439.0  False  Business Dev
# Mark          Male    4/12/08   57286.0   True  Business Dev
# Harold        Male     1/2/85   77544.0  False  Business Dev
# Jeffrey       Male    9/20/86  111376.0   True  Business Dev
# Matthew       Male     8/3/95  135352.0   True  Business Dev
# Clarence      Male    8/20/92  124365.0  False  Business Dev
# Lillian     Female    6/19/99  123940.0   True  Business Dev
# Brenda      Female    1/18/15   73749.0  False  Business Dev
# Linda       Female    5/25/00  119009.0   True  Business Dev

# %%
df2.sort_values(by='Mgmt', ascending=False).head(10)
# Out:
#             Gender Start Date    Salary  Mgmt          Team
# First Name
# Douglas       Male     8/6/93       NaN  True     Marketing
# Joseph        Male    9/10/92  102555.0  True       Product
# Clarence      Male    8/26/82  146589.0  True  Business Dev
# Cynthia     Female    9/14/91   51633.0  True  Business Dev
# Justin        Male     9/6/99   62454.0  True         Sales
# Ruby        Female     5/1/99  147362.0  True   Engineering
# Amanda      Female     8/1/04   80803.0  True  Distribution
# Roger         Male     7/3/10  105689.0  True     Marketing
# Julie          NaN     2/4/99   93302.0  True       Product
# Janice      Female     1/2/84   41190.0  True         Sales

# %%
df2.sort_values(
    by=['Team', 'Mgmt'],
    ascending=[True, False]
).tail(50)
# Out:
#              Gender Start Date    Salary   Mgmt   Team
# First Name
# NaN          Female    2/23/05  149654.0    NaN  Sales
# NaN             NaN    4/28/03  113732.0    NaN  Sales
# NaN            Male   11/25/99   42676.0    NaN  Sales
# NaN          Female     7/8/08   62960.0    NaN  Sales
# NaN            Male   10/13/83  139754.0    NaN  Sales
# NaN          Female    8/23/00   95866.0    NaN  Sales
# Thomas         Male    3/31/96   61933.0   True    NaN
# Louise       Female    8/12/80   63241.0   True    NaN
# Jonathan       Male    7/17/09  130581.0   True    NaN
# Jeremy         Male    6/14/88  129460.0   True    NaN
# Edward         Male     8/4/89   66067.0   True    NaN
# Joyce        Female     2/7/95   50701.0   True    NaN
# Jason          Male   11/20/98   69244.0   True    NaN
# Richard        Male     7/4/97   47647.0   True    NaN
# Peter          Male    2/22/03   56580.0   True    NaN
# Kimberly     Female   12/30/81   81800.0   True    NaN
# ...

# %%
df2
# Out:
#             Gender Start Date    Salary   Mgmt          Team
# First Name
# Douglas       Male     8/6/93       NaN   True     Marketing
# Thomas        Male    3/31/96   61933.0   True           NaN
# Maria       Female        NaN  130590.0  False       Finance
# Jerry          NaN     3/4/05  138705.0   True       Finance
# Larry         Male    1/24/98  101004.0   True            IT
# ...            ...        ...       ...    ...           ...
# Phillip       Male    1/31/84   42392.0  False       Finance
# Russell       Male    5/20/13   96914.0  False       Product
# Larry         Male    4/20/13   60500.0  False  Business Dev
# Albert        Male    5/15/12  129949.0   True         Sales
# NaN            NaN        NaN       NaN    NaN           NaN
#
# [1001 rows x 5 columns]

# %%
df2.sort_index()
# Out:
#             Gender Start Date    Salary   Mgmt          Team
# First Name
# Aaron         Male    2/17/12   61602.0   True     Marketing
# Aaron         Male    1/29/94   58755.0   True     Marketing
# Aaron         Male    7/22/90   52119.0   True            IT
# Aaron          NaN    1/22/86   63126.0  False            IT
# Adam          Male    5/21/11   95327.0  False  Distribution
# ...            ...        ...       ...    ...           ...
# NaN         Female    8/23/00   95866.0    NaN         Sales
# NaN         Female    9/15/85  133472.0    NaN  Distribution
# NaN           Male    7/30/12  107351.0    NaN     Marketing
# NaN         Female    9/14/10  143638.0    NaN           NaN
# NaN            NaN        NaN       NaN    NaN           NaN
#
# [1001 rows x 5 columns]

# %%
df2.sort_index(ascending=False)
# Out:
#             Gender Start Date    Salary   Mgmt          Team
# First Name
# Willie        Male   11/27/03   64363.0  False     Marketing
# Willie        Male    12/5/09  141932.0   True   Engineering
# Willie        Male    8/22/09   55038.0  False         Legal
# Willie        Male    2/17/98  146651.0   True   Engineering
# Willie        Male     6/6/06   55281.0   True     Marketing
# ...            ...        ...       ...    ...           ...
# NaN         Female    8/23/00   95866.0    NaN         Sales
# NaN         Female    9/15/85  133472.0    NaN  Distribution
# NaN           Male    7/30/12  107351.0    NaN     Marketing
# NaN         Female    9/14/10  143638.0    NaN           NaN
# NaN            NaN        NaN       NaN    NaN           NaN
#
# [1001 rows x 5 columns]

# %%
df2.sort_index(axis=1)
# Out:
#             Gender   Mgmt    Salary Start Date          Team
# First Name
# Douglas       Male   True       NaN     8/6/93     Marketing
# Thomas        Male   True   61933.0    3/31/96           NaN
# Maria       Female  False  130590.0        NaN       Finance
# Jerry          NaN   True  138705.0     3/4/05       Finance
# Larry         Male   True  101004.0    1/24/98            IT
# ...            ...    ...       ...        ...           ...
# Phillip       Male  False   42392.0    1/31/84       Finance
# Russell       Male  False   96914.0    5/20/13       Product
# Larry         Male  False   60500.0    4/20/13  Business Dev
# Albert        Male   True  129949.0    5/15/12         Sales
# NaN            NaN    NaN       NaN        NaN           NaN
#
# [1001 rows x 5 columns]

# %%
df2.sort_index(axis='columns')
# Out:
#             Gender   Mgmt    Salary Start Date          Team
# First Name
# Douglas       Male   True       NaN     8/6/93     Marketing
# Thomas        Male   True   61933.0    3/31/96           NaN
# Maria       Female  False  130590.0        NaN       Finance
# Jerry          NaN   True  138705.0     3/4/05       Finance
# Larry         Male   True  101004.0    1/24/98            IT
# ...            ...    ...       ...        ...           ...
# Phillip       Male  False   42392.0    1/31/84       Finance
# Russell       Male  False   96914.0    5/20/13       Product
# Larry         Male  False   60500.0    4/20/13  Business Dev
# Albert        Male   True  129949.0    5/15/12         Sales
# NaN            NaN    NaN       NaN        NaN           NaN
#
# [1001 rows x 5 columns]

# %%
df2
# Out:
#             Gender Start Date    Salary   Mgmt          Team
# First Name
# Douglas       Male     8/6/93       NaN   True     Marketing
# Thomas        Male    3/31/96   61933.0   True           NaN
# Maria       Female        NaN  130590.0  False       Finance
# Jerry          NaN     3/4/05  138705.0   True       Finance
# Larry         Male    1/24/98  101004.0   True            IT
# ...            ...        ...       ...    ...           ...
# Phillip       Male    1/31/84   42392.0  False       Finance
# Russell       Male    5/20/13   96914.0  False       Product
# Larry         Male    4/20/13   60500.0  False  Business Dev
# Albert        Male    5/15/12  129949.0   True         Sales
# NaN            NaN        NaN       NaN    NaN           NaN
#
# [1001 rows x 5 columns]

# %%
df2[['Gender', 'Team', 'Mgmt', 'Start Date', 'Salary']]
# Out:
#             Gender          Team   Mgmt Start Date    Salary
# First Name
# Douglas       Male     Marketing   True     8/6/93       NaN
# Thomas        Male           NaN   True    3/31/96   61933.0
# Maria       Female       Finance  False        NaN  130590.0
# Jerry          NaN       Finance   True     3/4/05  138705.0
# Larry         Male            IT   True    1/24/98  101004.0
# ...            ...           ...    ...        ...       ...
# Phillip       Male       Finance  False    1/31/84   42392.0
# Russell       Male       Product  False    5/20/13   96914.0
# Larry         Male  Business Dev  False    4/20/13   60500.0
# Albert        Male         Sales   True    5/15/12  129949.0
# NaN            NaN           NaN    NaN        NaN       NaN
#
# [1001 rows x 5 columns]

# %%
df2.reindex(
    columns=['Gender', 'Team', 'Mgmt', 'Start Date', 'Salary']
    )
# Out:
#             Gender          Team   Mgmt Start Date    Salary
# First Name
# Douglas       Male     Marketing   True     8/6/93       NaN
# Thomas        Male           NaN   True    3/31/96   61933.0
# Maria       Female       Finance  False        NaN  130590.0
# Jerry          NaN       Finance   True     3/4/05  138705.0
# Larry         Male            IT   True    1/24/98  101004.0
# ...            ...           ...    ...        ...       ...
# Phillip       Male       Finance  False    1/31/84   42392.0
# Russell       Male       Product  False    5/20/13   96914.0
# Larry         Male  Business Dev  False    4/20/13   60500.0
# Albert        Male         Sales   True    5/15/12  129949.0
# NaN            NaN           NaN    NaN        NaN       NaN
#
# [1001 rows x 5 columns]

# %%
df3 = pd.read_csv('C:/Users/Mahi/Desktop/project Pandas/Data/movies.csv')
df3.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#     release_date release_country  score      votes         director  \
# 0  June 13, 1980   United States    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980   United States    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980   United States    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980   United States    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980   United States    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df3.set_index(keys='name')
# Out:
#                                                rating      genre  year  \
# name
# The Shining                                         R      Drama  1980
# The Blue Lagoon                                     R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# Airplane!                                          PG     Comedy  1980
# Caddyshack                                          R     Comedy  1980
# ...                                               ...        ...   ...
# More to Life                                      NaN      Drama  2020
# Dream Round                                       NaN     Comedy  2020
# Saving Mbango                                     NaN      Drama  2020
# It's Just Us                                      NaN      Drama  2020
# Tee em el                                         NaN     Horror  2020
#
#                                                     release_date  \
# name
# ...

# %%
df3.set_index(keys='name', inplace=True)

# %%
df3
# Out:
#                                                rating      genre  year  \
# name
# The Shining                                         R      Drama  1980
# The Blue Lagoon                                     R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# Airplane!                                          PG     Comedy  1980
# Caddyshack                                          R     Comedy  1980
# ...                                               ...        ...   ...
# More to Life                                      NaN      Drama  2020
# Dream Round                                       NaN     Comedy  2020
# Saving Mbango                                     NaN      Drama  2020
# It's Just Us                                      NaN      Drama  2020
# Tee em el                                         NaN     Horror  2020
#
#                                                     release_date  \
# name
# ...

# %%
df3.set_index('release_date')
# Out:
#                  rating      genre  year release_country  score      votes  \
# release_date
# June 13, 1980         R      Drama  1980   United States    8.4   927000.0
# July 2, 1980          R  Adventure  1980   United States    5.8    65000.0
# June 20, 1980        PG     Action  1980   United States    8.7  1200000.0
# July 2, 1980         PG     Comedy  1980   United States    7.7   221000.0
# July 25, 1980         R     Comedy  1980   United States    7.3   108000.0
# ...                 ...        ...   ...             ...    ...        ...
# October 23, 2020    NaN      Drama  2020   United States    3.1       18.0
# February 7, 2020    NaN     Comedy  2020   United States    4.7       36.0
# April 27, 2020      NaN      Drama  2020        Cameroon    5.7       29.0
# October 1, 2020     NaN      Drama  2020   United States    NaN        NaN
# August 19, 2020     NaN     Horror  2020   United States    5.7        7.0
#
# ...

# %%
df3.reset_index()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7661                                    More to Life    NaN      Drama  2020
# 7662                                     Dream Round    NaN     Comedy  2020
# 7663                                   Saving Mbango    NaN      Drama  2020
# 7664                                    It's Just Us    NaN      Drama  2020
# 7665                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df4 = pd.read_csv(
        '../Data/employees.csv',
        index_col='First Name',
        parse_dates=['Start Date']
    )
df4.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df4 = pd.read_csv(
#       2         '../Data/employees.csv',
#       3         index_col='First Name',
#       4         parse_dates=['Start Date']
#       5     )
#       6 df4.head()
#
# ...

# %%
df4.dtypes

# %%
df4.Gender

# %%
df4.Gender.value_counts()

# %%
df4['Gender']

# %%
df4['Start Date']

# %%
df4[['Team', 'Mgmt']]

# %%
df4.select_dtypes(include='float64')

# %%
df4.select_dtypes(exclude='float64')

# %%
df4.select_dtypes(include='object')

# %%
df4.select_dtypes(include=['float64', 'object'])
