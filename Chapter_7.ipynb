# %% [markdown]
# <p dir = 'rtl'>    درس سوم بخش سوم </p>

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Mahi/Desktop/project Pandas/Data/movies.csv', index_col='name')
df.head()
# Out:
#                                                rating      genre  year  \
# name
# The Shining                                         R      Drama  1980
# The Blue Lagoon                                     R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# Airplane!                                          PG     Comedy  1980
# Caddyshack                                          R     Comedy  1980
#
#                                                  release_date release_country  \
# name
# The Shining                                     June 13, 1980   United States
# The Blue Lagoon                                  July 2, 1980   United States
# Star Wars: Episode V - The Empire Strikes Back  June 20, 1980   United States
# Airplane!                                        July 2, 1980   United States
# Caddyshack                                      July 25, 1980   United States
#
# ...

# %%
df.loc['A Beautiful Mind']
# Out:
# rating                          PG-13
# genre                       Biography
# year                             2001
# release_date          January 4, 2002
# release_country         United States
# score                             8.2
# votes                        871000.0
# director                   Ron Howard
# writer                 Akiva Goldsman
# star                    Russell Crowe
# country                 United States
# budget                     58000000.0
# gross                     316791257.0
# company            Universal Pictures
# runtime                         135.0
# Name: A Beautiful Mind, dtype: object

# %%
df.loc[['A Beautiful Mind', 'Good Will Hunting']]
# Out:
#                   rating      genre  year     release_date release_country  \
# name
# A Beautiful Mind   PG-13  Biography  2001  January 4, 2002   United States
# Good Will Hunting      R      Drama  1997  January 9, 1998   United States
#
#                    score     votes      director          writer  \
# name
# A Beautiful Mind     8.2  871000.0    Ron Howard  Akiva Goldsman
# Good Will Hunting    8.3  887000.0  Gus Van Sant      Matt Damon
#
#                              star        country      budget        gross  \
# name
# A Beautiful Mind    Russell Crowe  United States  58000000.0  316791257.0
# Good Will Hunting  Robin Williams  United States  10000000.0  225933435.0
#
#                               company  runtime
# name
# A Beautiful Mind   Universal Pictures    135.0
# Good Will Hunting             Miramax    126.0

# %%
df.head()
# Out:
#                                                rating      genre  year  \
# name
# The Shining                                         R      Drama  1980
# The Blue Lagoon                                     R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# Airplane!                                          PG     Comedy  1980
# Caddyshack                                          R     Comedy  1980
#
#                                                  release_date release_country  \
# name
# The Shining                                     June 13, 1980   United States
# The Blue Lagoon                                  July 2, 1980   United States
# Star Wars: Episode V - The Empire Strikes Back  June 20, 1980   United States
# Airplane!                                        July 2, 1980   United States
# Caddyshack                                      July 25, 1980   United States
#
# ...

# %%
df.iloc[0]
# Out:
# rating                           R
# genre                        Drama
# year                          1980
# release_date         June 13, 1980
# release_country      United States
# score                          8.4
# votes                     927000.0
# director           Stanley Kubrick
# writer                Stephen King
# star                Jack Nicholson
# country             United Kingdom
# budget                  19000000.0
# gross                   46998772.0
# company               Warner Bros.
# runtime                      146.0
# Name: The Shining, dtype: object

# %%
df.iloc[0:5]
# Out:
#                                                rating      genre  year  \
# name
# The Shining                                         R      Drama  1980
# The Blue Lagoon                                     R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# Airplane!                                          PG     Comedy  1980
# Caddyshack                                          R     Comedy  1980
#
#                                                  release_date release_country  \
# name
# The Shining                                     June 13, 1980   United States
# The Blue Lagoon                                  July 2, 1980   United States
# Star Wars: Episode V - The Empire Strikes Back  June 20, 1980   United States
# Airplane!                                        July 2, 1980   United States
# Caddyshack                                      July 25, 1980   United States
#
# ...

# %%
df.iloc[-1]
# Out:
# rating                          NaN
# genre                        Horror
# year                           2020
# release_date        August 19, 2020
# release_country       United States
# score                           5.7
# votes                           7.0
# director               Pereko Mosia
# writer                 Pereko Mosia
# star               Siyabonga Mabaso
# country                South Africa
# budget                          NaN
# gross                           NaN
# company                 PK 65 Films
# runtime                       102.0
# Name: Tee em el, dtype: object

# %%
df.iloc[-2]
# Out:
# rating                         NaN
# genre                        Drama
# year                          2020
# release_date       October 1, 2020
# release_country      United States
# score                          NaN
# votes                          NaN
# director             James Randall
# writer               James Randall
# star                 Christina Roz
# country              United States
# budget                     15000.0
# gross                          NaN
# company                        NaN
# runtime                      120.0
# Name: It's Just Us, dtype: object

# %%
df.iloc[-5:]
# Out:
#               rating   genre  year      release_date release_country  score  \
# name
# More to Life     NaN   Drama  2020  October 23, 2020   United States    3.1
# Dream Round      NaN  Comedy  2020  February 7, 2020   United States    4.7
# Saving Mbango    NaN   Drama  2020    April 27, 2020        Cameroon    5.7
# It's Just Us     NaN   Drama  2020   October 1, 2020   United States    NaN
# Tee em el        NaN  Horror  2020   August 19, 2020   United States    5.7
#
#                votes       director         writer              star  \
# name
# More to Life    18.0  Joseph Ebanks  Joseph Ebanks      Shannon Bond
# Dream Round     36.0   Dusty Dukatz    Lisa Huston  Michael Saquella
# Saving Mbango   29.0   Nkanya Nkwai   Lynno Lovert      Onyama Laura
# It's Just Us     NaN  James Randall  James Randall     Christina Roz
# Tee em el        7.0   Pereko Mosia   Pereko Mosia  Siyabonga Mabaso
#
#                      country   budget  gross                    company  \
# ...

# %%
df.sort_values(by='score', ascending=False).iloc[0:5]
# Out:
#                                               rating      genre  year  \
# name
# The Shawshank Redemption                           R      Drama  1994
# The Dark Knight                                PG-13     Action  2008
# The Lord of the Rings: The Return of the King  PG-13     Action  2003
# Pulp Fiction                                       R      Crime  1994
# Schindler's List                                   R  Biography  1993
#
#                                                     release_date  \
# name
# The Shawshank Redemption                        October 14, 1994
# The Dark Knight                                    July 18, 2008
# The Lord of the Rings: The Return of the King  December 17, 2003
# Pulp Fiction                                    October 14, 1994
# Schindler's List                                February 4, 1994
#
#                                               release_country  score  \
# name
# ...

# %%
df.sort_values(by='score', ascending=False).iloc[-5:]
# Out:
#                              rating   genre  year       release_date  \
# name
# The Hottie & the Nottie       PG-13  Comedy  2008  February 21, 2008
# Superbabies: Baby Geniuses 2     PG  Comedy  2004    August 27, 2004
# Love by Drowning                  R   Drama  2020   November 6, 2020
# The Robinsons                   NaN  Action  2020  November 10, 2020
# It's Just Us                    NaN   Drama  2020    October 1, 2020
#
#                              release_country  score    votes  \
# name
# The Hottie & the Nottie               Russia    1.9  36000.0
# Superbabies: Baby Geniuses 2   United States    1.9  30000.0
# Love by Drowning               United States    NaN      NaN
# The Robinsons                  United States    NaN      NaN
# It's Just Us                   United States    NaN      NaN
#
#                                        director                writer  \
# name
# The Hottie & the Nottie              Tom Putnam          Heidi Ferrer
# ...

# %%
df.loc['Inception']
# Out:
# rating                         PG-13
# genre                         Action
# year                            2010
# release_date           July 16, 2010
# release_country        United States
# score                            8.8
# votes                      2100000.0
# director           Christopher Nolan
# writer             Christopher Nolan
# star               Leonardo DiCaprio
# country                United States
# budget                   160000000.0
# gross                    836836967.0
# company                 Warner Bros.
# runtime                        148.0
# Name: Inception, dtype: object

# %%
df.loc['Inception']['runtime']
# Out:
# 148.0

# %%
df.loc['Inception','runtime']
# Out:
# 148.0

# %%
df.loc['Inception',['runtime','budget','gross']]
# Out:
# runtime          148.0
# budget     160000000.0
# gross      836836967.0
# Name: Inception, dtype: object

# %%
df.iloc[10]
# Out:
# rating                              PG
# genre                           Action
# year                              1980
# release_date         December 17, 1980
# release_country          United States
# score                              6.1
# votes                          18000.0
# director                Buddy Van Horn
# writer                Stanford Sherman
# star                    Clint Eastwood
# country                  United States
# budget                      15000000.0
# gross                       70687344.0
# company            The Malpaso Company
# runtime                          116.0
# Name: Any Which Way You Can, dtype: object

# %%
df.iloc[10]['runtime']
# Out:
# 116.0

# %%
df.iloc[10,'runtime']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File g:\Python\Lib\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     965 try:
# --> 966     self._validate_key(k, i)
#     967 except ValueError as err:
#
# File g:\Python\Lib\site-packages\pandas\core\indexing.py:1614, in _iLocIndexer._validate_key(self, key, axis)
#    1613 else:
# -> 1614     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df.iloc[10,'runtime']
#
# ...

# %%
df.iloc[10,14]

# %%
df.iloc[10,[14,11,12]]

# %%
RUNTIME = 14
BUDGET = 11
GROSS = 12

df.iloc[10,[RUNTIME, BUDGET, GROSS]]

# %%
df.iloc[0:5]

# %%
df.loc['The Shining':'Airplane!']

# %%
df.sort_index().loc['Inception':'Interstellar']

# %%
df.loc['The Green Mile','runtime']

# %%
# %%timeit
df.loc['The Green Mile','runtime']

# %%
# %%timeit
df.at['The Green Mile','runtime']

# %%
# %%timeit
df.iat[0,RUNTIME]

# %%
# %%timeit
df.iloc[0,RUNTIME]

# %%
s = df.score

# %%
s.iloc[0]

# %%
s

# %%
s.loc['In Time']

# %%
s.at['In Time']

# %%
df2 = pd.read_csv(
        'C:/Users/Mahi/Desktop/project Pandas/Data/employees.csv',
        index_col='First Name',
        parse_dates=['Start Date'],
)
df2.head()

# %%
df2.columns

# %%
df2.columns = ['gender', 'start_date', 'salary', 'management', 'team']

# %%
df2

# %%
df2.rename(columns={'start_date':'emp_date'})

# %%
df2.loc['Douglas']

# %%
df2.rename(index={'Douglas':'Douglass'}, inplace=True)

# %%
df2.loc['Douglass']

# %%
df2.rename(index={'Douglass':'Douglas'}, inplace=True)

# %%
df2.head()

# %%
df3 = pd.read_csv('../Data/used_cars.csv')
df3.info()

# %%
df3['Fuel'].value_counts()

# %%
df3['Fuel'].astype('category')

# %%
df3['Fuel'] = df['Fuel'].astype('category')
df3.info()

# %%
df3['Transmission'].value_counts()

# %%
df3['Transmission'] = df['Transmission'].astype('category')

# %%
df3.info()

# %%
df3['Manufacturer'].value_counts()

# %%
df3['Manufacturer'].nunique()

# %%
df3['Manufacturer'] = df['Manufacturer'].astype('category')
df3.info()

# %%
16.6/7.9
